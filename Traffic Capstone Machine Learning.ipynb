# %%
import matplotlib  
import matplotlib.pyplot as plt 
import numpy as np 
from sklearn import datasets, linear_model 
import pandas as pd 

# %store -r temp_data 
   
Y = temp_data.index.values
X = temp_data.values
   
X=X.reshape(len(X),1) 
Y=Y.reshape(len(Y),1) 
   
# Split the data into training/testing sets 
X_train = X[:-250] 
X_test = X[-250:] 
   
# Split the targets into training/testing sets 
Y_train = Y[:-250] 
Y_test = Y[-250:] 
   
# Plot outputs 
plt.scatter(X_test, Y_test,  color='black') 
plt.title('Temperature Model') 
plt.xlabel('Temperature (°F)') 
plt.ylabel('Traffic Volume') 
plt.xticks(()) 
plt.yticks(()) 
# Create linear regression object 
regr = linear_model.LinearRegression() 
   
# Train the model using the training sets 
# Train the model using the training sets 
regr.fit(X_test, Y_test) 
   
# Plot outputs 
plt.plot(X_test, regr.predict(X_test), color='red',linewidth=3) 
plt.show()

# %%
# %store -r Rain_Data
   
Y = Rain_Data.index.values
X = Rain_Data.values
   
X=X.reshape(len(X),1) 
Y=Y.reshape(len(Y),1) 
   
# Split the data into training/testing sets 
X_train = X[:-250] 
X_test = X[-250:] 
   
# Split the targets into training/testing sets 
Y_train = Y[:-250] 
Y_test = Y[-250:] 
   
# Plot outputs 
plt.scatter(X_test, Y_test,  color='black') 
plt.title('Rain') 
plt.xlabel('Rain(mm) Over 1Hr') 
plt.ylabel('Traffic Volume') 
plt.xticks(()) 
plt.yticks(()) 

# Create linear regression object 
regr = linear_model.LinearRegression() 
   
# Train the model using the training sets 
# Train the model using the training sets 
regr.fit(X_test, Y_test) 
   
# Plot outputs 
plt.plot(X_test, regr.predict(X_test), color='red',linewidth=3) 
plt.show()

# %%
# %store -r Snow_Data
   
Y = Snow_Data.index.values
X = Snow_Data.values
   
X=X.reshape(len(X),1) 
Y=Y.reshape(len(Y),1) 
   
# Split the data into training/testing sets 
X_train = X[:-250] 
X_test = X[-250:] 
   
# Split the targets into training/testing sets 
Y_train = Y[:-250] 
Y_test = Y[-250:] 
   
# Plot outputs 
plt.scatter(X_test, Y_test,  color='black') 
plt.title('Snow') 
plt.xlabel('Snow(mm) Over 1Hr') 
plt.ylabel('Traffic Volume') 
plt.xticks(()) 
plt.yticks(()) 
# Create linear regression object 
regr = linear_model.LinearRegression() 
   
# Train the model using the training sets 
# Train the model using the training sets 
regr.fit(X_test, Y_test) 
   
# Plot outputs 
plt.plot(X_test, regr.predict(X_test), color='red',linewidth=3) 
plt.show()

# %%
# %store -r dfb
   
Y = dfb.index.values
X = dfb.values
   
X=X.reshape(len(X),1) 
Y=Y.reshape(len(Y),1) 
   
# Split the data into training/testing sets 
X_train = X[:-250] 
X_test = X[-250:] 
   
# Split the targets into training/testing sets 
Y_train = Y[:-250] 
Y_test = Y[-250:] 
   
# Plot outputs 
plt.scatter(X_test, Y_test,  color='black') 
plt.title('Cloud Coverage') 
plt.xlabel('Percent of Cloud Coverage') 
plt.ylabel('Traffic Volume') 
plt.xticks(()) 
plt.yticks(()) 
# Create linear regression object 
# Train the model using the training sets 
regr.fit(X_test, Y_test) 
   
# Plot outputs 
plt.plot(X_test, regr.predict(X_test), color='red',linewidth=3) 
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
# %store -r holiday_data
gle = LabelEncoder()
genre_labels = gle.fit_transform(holiday_data)
genre_mappings = {index: label for index, label in 
                  enumerate(gle.classes_)}
genre_mappings

# %store -r holiday_data
   
Y = np.array(list(genre_mappings.values()))
X = holiday_data.values
   
X=X.reshape(len(X),1) 
Y=Y.reshape(len(Y),1) 
   
# Split the data into training/testing sets 
X_train = X[:-250] 
X_test = X[-250:] 
   
# Split the targets into training/testing sets 
Y_train = Y[:-250] 
Y_test = Y[-250:] 
   
# Plot outputs 
plt.scatter(X_test, Y_test,  color='black') 
plt.title('Holidays') 
plt.xlabel('Holiday') 
plt.ylabel('Traffic Volume') 
plt.xticks(()) 
plt.yticks(()) 
# Train the model using the training sets 
regr.fit(X_test, Y_test) 
   
# Plot outputs 
plt.plot(X_test, regr.predict(X_test), color='red',linewidth=3) 
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
# %store -r Weather_Data
gle = LabelEncoder()
genre_labels = gle.fit_transform( Weather_Data)
genre_mappings = {index: label for index, label in 
                  enumerate(gle.classes_)}
genre_mappings
   
Y = np.array(list(genre_mappings.values()))
X =  Weather_Data.values
   
X=X.reshape(len(X),1) 
Y=Y.reshape(len(Y),1) 
   
# Split the data into training/testing sets 
X_train = X[:-250] 
X_test = X[-250:] 
   
# Split the targets into training/testing sets 
Y_train = Y[:-250] 
Y_test = Y[-250:] 
   
# Plot outputs 
plt.scatter(X_test, Y_test,  color='black') 
plt.title('Weather Type') 
plt.xlabel('Weather Type') 
plt.ylabel('Traffic Volume') 
plt.xticks(()) 
plt.yticks(()) 
  
# Train the model using the training sets 
regr.fit(X_test, Y_test) 
   
# Plot outputs 
plt.plot(X_test, regr.predict(X_test), color='red',linewidth=3) 
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
# %store -r Weather_Description_Data
gle = LabelEncoder()
genre_labels = gle.fit_transform( Weather_Description_Data)
genre_mappings = {index: label for index, label in 
                  enumerate(gle.classes_)}
genre_mappings
   
Y = np.array(list(genre_mappings.values()))
X =  Weather_Description_Data.values
   
X=X.reshape(len(X),1) 
Y=Y.reshape(len(Y),1) 
   
# Split the data into training/testing sets 
X_train = X[:-250] 
X_test = X[-250:] 
   
# Split the targets into training/testing sets 
Y_train = Y[:-250] 
Y_test = Y[-250:] 
   
# Plot outputs 
plt.scatter(X_test, Y_test,  color='black') 
plt.title('Weather Description') 
plt.xlabel('Weather Description') 
plt.ylabel('Traffic Volume') 
plt.xticks(()) 
plt.yticks(()) 
  
# Train the model using the training sets 
regr.fit(X_test, Y_test) 
   
# Plot outputs 
plt.plot(X_test, regr.predict(X_test), color='red',linewidth=3) 
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
# %store -r Month_Data
gle = LabelEncoder()
genre_labels = gle.fit_transform( Month_Data)
genre_mappings = {index: label for index, label in 
                  enumerate(gle.classes_)}
genre_mappings
   
Y = np.array(list(genre_mappings.values()))
X =  Month_Data.values
   
X=X.reshape(len(X),1) 
Y=Y.reshape(len(Y),1) 
   
# Split the data into training/testing sets 
X_train = X[:-250] 
X_test = X[-250:] 
   
# Split the targets into training/testing sets 
Y_train = Y[:-250] 
Y_test = Y[-250:] 
   
# Plot outputs 
plt.scatter(X_test, Y_test,  color='black') 
plt.title('Time(months)') 
plt.xlabel('Time(months)') 
plt.ylabel('Traffic Volume') 
plt.xticks(()) 
plt.yticks(()) 
  
# Train the model using the training sets 
regr.fit(X_test, Y_test) 
   
# Plot outputs 
plt.plot(X_test, regr.predict(X_test), color='red',linewidth=3) 
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
# %store -r Hour_Data
gle = LabelEncoder()
genre_labels = gle.fit_transform(Hour_Data)
genre_mappings = {index: label for index, label in 
                  enumerate(gle.classes_)}
genre_mappings
   
Y = np.array(list(genre_mappings.values()))
X =  Hour_Data.values
   
X=X.reshape(len(X),1) 
Y=Y.reshape(len(Y),1) 
   
# Split the data into training/testing sets 
X_train = X[:-250] 
X_test = X[-250:] 
   
# Split the targets into training/testing sets 
Y_train = Y[:-250] 
Y_test = Y[-250:] 
   
# Plot outputs 
plt.scatter(X_test, Y_test,  color='black') 
plt.title('Time(hours)') 
plt.xlabel('Time(hours)') 
plt.ylabel('Traffic Volume') 
plt.xticks(()) 
plt.yticks(()) 
  
# Train the model using the training sets 
regr.fit(X_test, Y_test) 
   
# Plot outputs 
plt.plot(X_test, regr.predict(X_test), color='red',linewidth=3) 
plt.show()
